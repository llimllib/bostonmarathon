# %%
# %matplotlib inline

import cPickle
import matplotlib.pyplot as plt
import matplotlib
import mpld3, mpld3.plugins
import numpy as np
from collections import Counter

# %%
runners = cPickle.load(file("results/2013/results.pkl"))

# %%
runners["1"]
# Out:
# {'10k': u'0:30:54',
#  '20k': u'1:01:31',
#  '25k': u'1:17:16',
#  '30k': u'1:32:58',
#  '35k': u'1:48:47',
#  '40k': u'2:04:46',
#  '5k': u'0:15:54',
#  'age': u'30',
#  'bib': u'1',
#  'city': u'Kenya',
#  'country': u'KEN',
#  'ctz': u'',
#  'division': u'5',
#  'gender': u'M',
#  'genderdiv': u'5',
#  'half': u'1:04:54',
#  'name': u'Korir, Wesley',
#  'official': u'2:12:30',
#  'overall': u'5',
#  'pace': u'0:05:04',
#  'state': u''}

# %%
def bar(xs, ys):
    fig = plt.figure(figsize=(8,5))
    ax = fig.add_subplot(111, axisbg='#EEEEEE')
    ax.grid(color='white', linestyle='solid')
    ax.bar(xs, ys, fc='lightblue', alpha=0.8, edgecolor="white")

# %%
ages = Counter(int(x['age']) for x in runners.itervalues())
xs = range(min(ages.keys()), max(ages.keys()))
ys = [ages[i] for i in xs]
bar(xs, ys)
mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el162444278237604564379840"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el162444278237604564379840", {"axes": [{"xlim": [10.0, 80.0], "yscale": "linear", "axesbg": "#EEEEEE", "texts": [], "zoomable": true, "images": [], "xdomain": [10.0, 80.0], "ylim": [0.0, 700.0], "paths": [{"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.8, "xindex": 0, "data": "data01", "id": "el16244434453584"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.8, "xindex": 0, "data": "data02", "id": "el16244434455120"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.8, "xindex": 0, "data": "data03", "id": "el16244434456400"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.8, "xindex": 0, "data": "data04", "id": "el16244434483088"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.8, "xindex": 0, "data": "data05", "id": "el16244434484752"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.8, "xindex": 0, "data": "data06", "id": "el16244434498768"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.8, "xindex": 0, "data": "data07", "id": "el16244434500432"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.8, "xindex": 0, "data": "data08", "id": "el16244434510352"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.8, "xindex": 0, "data": "data09", "id": "el16244434512016"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.8, "xindex": 0, "data": "data10", "id": "el16244434513680"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.8, "xindex": 0, "data": "data11", "id": "el16244434531792"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.8, "xindex": 0, "data": "data12", "id": "el16244434533456"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.8, "xindex": 0, "data": "data13", "id": "el16244434547472"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.8, "xindex": 0, "data": "data14", "id": "el16244434549136"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 0.8, "xindex": 2, "data": "data10", "id": "el16244434550416"}, {"edgecolor": "#FFFFFF", "face ...

# %%
from collections import Counter
men = Counter(int(x['age']) for x in runners.itervalues() if x['gender']=="M")
mxs = range(min(men.keys()), max(men.keys()))
mys = [men[i] for i in mxs]

wmn = Counter(int(x['age']) for x in runners.itervalues() if x['gender']=="F")
wxs = range(min(wmn.keys()), max(wmn.keys()))
wys = [wmn[i] for i in wxs]

fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111, axisbg='#EEEEEE', title="2013 Boston Marathon participants, by age and gender")
ax.grid(color='white', linestyle='solid')
b1 = ax.bar(mxs, mys, color='lightblue', alpha=1, edgecolor="white", label="Men")
b2 = ax.bar(wxs, wys, color='pink', alpha=0.6, edgecolor="white", label="Women")
ax.legend()

mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el162444344084644606664119"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el162444344084644606664119", {"axes": [{"xlim": [10.0, 80.0], "yscale": "linear", "axesbg": "#EEEEEE", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#000000", "text": "2013 Boston Marathon participants, by age and gender", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0179211469534051], "rotation": -0.0, "id": "el16244427230352"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Men", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [0.90148689516129055, 0.92903225806451595], "rotation": -0.0, "id": "el16244437125840"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Women", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [0.90148689516129055, 0.86559139784946215], "rotation": -0.0, "id": "el16244437127056"}], "zoomable": true, "images": [], "xdomain": [10.0, 80.0], "ylim": [0.0, 450.0], "paths": [{"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data01", "id": "el16244436565136"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data02", "id": "el16244436562832"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data03", "id": "el16244436565968"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data04", "id": "el16244435460944"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data05", "id": "el16244435462544"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data06", "id": "el16244436550608"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data07", "id": "el16244436550288"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data08", "id": "el16244436552720"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data09", "id": "el16244434577040"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data10", "id": "el16244434577872"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data11", "id": "el16244434531344"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data12", "id": "el16244434533008"}, {"edgecolor":  ...

# %%
def minutes(time):
    parts = [int(x) for x in runners[105]['official'].split(':')]
    return parts[0] * 60 + parts[1] + parts[2]/60.
# Out:
# ([2, 19, 35], 139.58333333333334)

# %%
two = runners = cPickle.load(file("results/2014/results.pkl"))

# %%
max(int(t) for t in two if t.isdigit())
# Out:
# 27050

# %%
len(two)
# Out:
# 17652

# %%
two['1']
# Out:
# {'10k': u'0:30:54',
#  '20k': u'1:01:31',
#  '25k': u'1:17:16',
#  '30k': u'1:32:58',
#  '35k': u'1:48:47',
#  '40k': u'2:04:46',
#  '5k': u'0:15:54',
#  'age': u'30',
#  'bib': u'1',
#  'city': u'Kenya',
#  'country': u'KEN',
#  'ctz': u'',
#  'division': u'5',
#  'gender': u'M',
#  'genderdiv': u'5',
#  'half': u'1:04:54',
#  'name': u'Korir, Wesley',
#  'official': u'2:12:30',
#  'overall': u'5',
#  'pace': u'0:05:04',
#  'state': u''}

# %%
r2014 = cPickle.load(file("results/2014/results.pkl"))

# %%
len(r2014)
# Out:
# 31984

# %%
r2014["30592"]
# Out:
# {'10k': u'1:05:10',
#  '20k': u'2:09:08',
#  '25k': u'2:48:22',
#  '30k': u'3:25:35',
#  '35k': u'4:14:55',
#  '40k': u'5:19:26',
#  '5k': u'0:33:01',
#  'age': u'37',
#  'bib': u'30592',
#  'city': u'Portland',
#  'country': u'USA',
#  'ctz': u'',
#  'division': u'6476',
#  'gender': u'F',
#  'genderdiv': u'13327',
#  'half': u'2:16:18',
#  'name': u'Wood, Samantha L.',
#  'official': u'5:39:06',
#  'overall': u'30071',
#  'pace': u'0:12:57',
#  'state': u'ME'}

# %%
from collections import Counter
men = Counter(int(x['age']) for x in r2014.itervalues() if x['gender']=="M")
mxs = range(min(men.keys()), max(men.keys()))
mys = [men[i] for i in mxs]

wmn = Counter(int(x['age']) for x in r2014.itervalues() if x['gender']=="F")
wxs = range(min(wmn.keys()), max(wmn.keys()))
wys = [wmn[i] for i in wxs]

fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111, axisbg='#EEEEEE', title="2014 Boston Marathon participants, by age and gender")
ax.grid(color='white', linestyle='solid')
b1 = ax.bar(mxs, mys, color='lightblue', alpha=1, edgecolor="white", label="Men")
b2 = ax.bar(wxs, wys, color='pink', alpha=0.6, edgecolor="white", label="Women")
ax.legend()

mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el289946349127206306742769"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el289946349127206306742769", {"axes": [{"xlim": [10.0, 90.0], "yscale": "linear", "axesbg": "#EEEEEE", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#000000", "text": "2014 Boston Marathon participants, by age and gender", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0179211469534051], "rotation": -0.0, "id": "el28994636079504"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Men", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [0.90148689516129055, 0.92903225806451595], "rotation": -0.0, "id": "el28994643891856"}, {"v_baseline": "auto", "h_anchor": "start", "color": "#000000", "text": "Women", "coordinates": "axes", "zorder": 1000003.0, "alpha": 1, "fontsize": 12.0, "position": [0.90148689516129055, 0.86559139784946215], "rotation": -0.0, "id": "el28994643893136"}], "zoomable": true, "images": [], "xdomain": [10.0, 90.0], "ylim": [0.0, 700.0], "paths": [{"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data01", "id": "el28994643095888"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data02", "id": "el28994643097552"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data03", "id": "el28994643115664"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data04", "id": "el28994643117328"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data05", "id": "el28994643118992"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data06", "id": "el28994643133008"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data07", "id": "el28994643134672"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data08", "id": "el28994643140496"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data09", "id": "el28994643142160"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data10", "id": "el28994643143440"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data11", "id": "el28994643166032"}, {"edgecolor": "#FFFFFF", "facecolor": "#ADD8E6", "edgewidth": 1.0, "pathcodes": ["M", "L", "L", "L", "Z"], "yindex": 1, "coordinates": "data", "dasharray": "10,0", "zorder": 1, "alpha": 1, "xindex": 0, "data": "data12", "id": "el28994643167696"}, {"edgecolor":  ...
